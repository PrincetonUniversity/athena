# %%
# %matplotlib inline
# fix DPI issues on mac
# %config InlineBackend.figure_format = 'retina'
 # autoreload workflow, reload modules every time cell is run
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import matplotlib.pyplot as plt
default_color_list = plt.rcParams['axes.prop_cycle'].by_key()['color'] # get default colors
import matplotlib
matplotlib.rcParams['figure.figsize'] = 10,8 # have to fix figure size due to backend
from astropy.io import ascii   
from scipy.special import erf

# %%
import yt

# Load the dataset.
ds = yt.load("SN.out2.00101.athdf")
ad = ds.all_data()
# Out:
# yt : [WARNING  ] 2018-03-10 04:28:51,744 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2018-03-10 04:28:51,745 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2018-03-10 04:28:51,746 Assuming 1.0 = 1.0 g
# yt : [WARNING  ] 2018-03-10 04:28:51,747 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2018-03-10 04:28:51,767 Parameters: current_time              = 10000000.0
# yt : [INFO     ] 2018-03-10 04:28:51,769 Parameters: domain_dimensions         = [256   4   4]
# yt : [INFO     ] 2018-03-10 04:28:51,771 Parameters: domain_left_edge          = [  2.20000000e+13   0.00000000e+00   0.00000000e+00]
# yt : [INFO     ] 2018-03-10 04:28:51,772 Parameters: domain_right_edge         = [  6.00000000e+13   3.14159265e+00   6.28318531e+00]
# yt : [INFO     ] 2018-03-10 04:28:51,773 Parameters: cosmological_simulation   = 0.0

# %%
dir(ds.fields.athena_pp)
# Out:
# ['cell_volume',
#  'dphi',
#  'dr',
#  'dtheta',
#  'path_element_phi',
#  'path_element_r',
#  'path_element_theta',
#  'phi',
#  'r',
#  'theta',
#  'user_out_var0',
#  'user_out_var1']

# %%
# slc = yt.SlicePlot(ds, 'phi', 'user_out_var1', center=[0.0, 0.0, 0.0])
# slc.show()

# %%
r = np.array(ad['r']).reshape(256,4,4)
var0 = np.array(ad['user_out_var0']).reshape(256,4,4)
var1 = np.array(ad['user_out_var1']).reshape(256,4,4)
plt.plot( r[:,0,0], var0[:,0,0] )

# %%
plt.plot( r[:,0,0], var1[:,0,0] )
