# %%
# %matplotlib inline
# fix DPI issues on mac
# %config InlineBackend.figure_format = 'retina'
 # autoreload workflow, reload modules every time cell is run
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import matplotlib.pyplot as plt
default_color_list = plt.rcParams['axes.prop_cycle'].by_key()['color'] # get default colors
import matplotlib
from astropy.table import Table
from scipy.special import erf
import h5py

# %%
data_size = 7000

# %%
def get_prim(filename, custom=0):
    
    f = h5py.File(filename, 'r')
    dataset = f['prim']
    dd = np.array(dataset).reshape(5,data_size)
    r = f['x1v'][0]
    
    # rho, press, vel1, vel2, vel3
    return r, dd[custom]
    # data1.colnames

# %%
def plot_prim(filename, custom=0):
    
    f = h5py.File(filename, 'r')
    dataset = f['prim']
    dd = np.array(dataset).reshape(5,data_size)
    r = f['x1v'][0]
    
    # rho, press, vel1, vel2, vel3

    # data1.colnames
    plt.plot( r, dd[custom], label='t=0 s' )
    # plt.plot( r, data2['rho'], label=r't=$5 \times 10^4$ s' )
    # plt.plot( r, data3['rho'], label=r't=$10 \times 10^4$ s' )

#     plt.plot( s13['col2'], s13['col4'] )

    plt.ylabel(r'$\rho$ (g/cm$^3$)')
    plt.xlabel(r'$r$ (cm)')
    plt.legend()
#     plt.yscale('log')

# %%
def get_uov(filename, custom=0):
    
    f = h5py.File(filename, 'r')
    dataset = f['hydro']
    dd = np.array(dataset).reshape(2,data_size)
    r = f['x1v'][0]
    return r, dd[custom]

# %%
def plot_uov(filename, custom=0):
    r, ddcustom = get_uov(filename, custom)
    # rho, press, vel1, vel2, vel3
    plt.plot( r, ddcustom, label='simulation' )

# %%
r, src_over_rho = get_uov('SN.out2.' + str(2).zfill(5) + '.athdf',0)
r, rho = get_prim('SN.out1.' + str(2).zfill(5) + '.athdf', 0)
r, P = get_prim('SN.out1.' + str(2).zfill(5) + '.athdf', 1)
    
plt.plot( r, src_over_rho*rho, '--' )
plt.plot( r, -np.gradient(P,r), '--' )
plt.yscale('log')
plt.tight_layout()
# plt.xlim(0,2e13)

# %%
from matplotlib import animation, rc
from IPython.display import HTML

# First set up the figure, the axis, and the plot element we want to animate
fig, ax = plt.subplots(figsize=(9,8))

ax.set_xlim((0.5e13,6.5e13 ))
ax.set_ylim((-3e-7,2e-6))
# ax.set_yscale('log')

line1, = ax.plot([], [], lw=2, label=r'$\rho \nabla \Phi$')
line2, = ax.plot([], [], lw=1, label=r'$-\nabla P$')
time_text = ax.text(0.02, 0.92, '', transform=ax.transAxes, fontsize=20)

ax.ticklabel_format(axis='y', style='sci', scilimits=(0,0))

# initialization function: plot the background of each frame
def init():
    line1.set_data([], [])
    line2.set_data([], [])
    return (line1,)

# animation function. This is called sequentially
def animate(i):
    
    r, src_over_rho = get_uov('SN.out2.' + str(i).zfill(5) + '.athdf',0)
    r, rho = get_prim('SN.out1.' + str(i).zfill(5) + '.athdf', 0)
    r, P = get_prim('SN.out1.' + str(i).zfill(5) + '.athdf', 1)
    
    time_text.set_text('time = %.2e' %  (i*1e4) )
    
    line1.set_data(r,src_over_rho*rho)
    line2.set_data(r, -np.gradient(P,r))
    return (line1,)

ax.autoscale(enable=False, axis='both', tight=None)
fig.subplots_adjust(left=0.1, bottom=0.2, right=1, top=0.9, wspace=0.1, hspace=0.1)
ax.set_xlabel('radius (cm)')
ax.legend();

# %%
# call the animator. blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=13, interval=20, blit=True)
HTML(anim.to_html5_video())
# Out:
# <video width="648" height="576" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %%
plot_prim('SN.out1.00500.athdf',0)

# %%
from matplotlib import animation, rc
from IPython.display import HTML

# First set up the figure, the axis, and the plot element we want to animate
fig, ax = plt.subplots(figsize=(9,8))

ax.set_xlim((0.5e13,6.5e13 ))
ax.set_ylim((1e-15,3e-7))
# ax.set_yscale('log')

line1, = ax.plot([], [], lw=2, label=r'$\rho_0$')
line2, = ax.plot([], [], lw=1, label=r'$\rho(t)$')
time_text = ax.text(0.02, 0.92, '', transform=ax.transAxes, fontsize=20)

ax.ticklabel_format(axis='y', style='sci', scilimits=(0,0))

# initialization function: plot the background of each frame
def init():
    line1.set_data([], [])
    line2.set_data([], [])
    return (line1,)


r, rho0 = get_prim('SN.out1.' + str(0).zfill(5) + '.athdf', 0)
# animation function. This is called sequentially
def animate(i):
    
    r, rho = get_prim('SN.out1.' + str(i).zfill(5) + '.athdf', 0)
    
    time_text.set_text('time = %.2e' %  (i*1e4) )
    
    line1.set_data(r, rho0)
    line2.set_data(r, rho)
    return (line1,)

ax.autoscale(enable=False, axis='both', tight=None)
fig.subplots_adjust(left=0.2, bottom=0.2, right=0.95, top=0.9, wspace=0.1, hspace=0.1)
ax.set_xlabel('radius (cm)')
ax.set_yscale('log')
ax.legend();

# %%
# call the animator. blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=500, interval=20, blit=True)
HTML(anim.to_html5_video())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-c6888b630ef4> in <module>()
#       2 anim = animation.FuncAnimation(fig, animate, init_func=init,
#       3                                frames=500, interval=20, blit=True)
# ----> 4 HTML(anim.to_html5_video())
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/animation.py in to_html5_video(self, embed_limit)
#    1350                                 bitrate=rcParams['animation.bitrate'],
#    1351                                 fps=1000. / self._interval)
# -> 1352                 self.save(f.name, writer=writer)
#    1353
#    1354             # Now open and base64 encode
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs)
#    1196                     for anim, d in zip(all_anim, data):
#    1197                         # TODO: See if turning off blit is really necessary
# -> 1198                         anim._draw_next_frame(d, blit=False)
#    1199                     writer.grab_frame(**savefig_kwargs)
#    1200
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/animation.py in _draw_next_frame(self, framedata, blit)
#    1233         # post- draw, as well as the drawing of the frame itself.
#    1234         self._pre_draw(framedata, blit)
# -> 1235         self._draw_frame(framedata)
#    1236         self._post_draw(framedata, blit)
#    1237
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/animation.py in _draw_frame(self, framedata)
#    1769         # Call the func with framedata and args. If blitting is desired,
#    1770         # func needs to return a sequence of any artists that were modified.
# -> 1771         self._drawn_artists = self._func(framedata, *self._args)
#    1772         if self._blit:
#    1773             if self._drawn_artists is None:
#
# <ipython-input-47-5b091f8c087a> in animate(i)
#      24 def animate(i):
#      25
# ---> 26     r, src_over_rho = get_uov('SN.out2.' + str(i).zfill(5) + '.athdf',0)
#      27     r, rho = get_prim('SN.out1.' + str(i).zfill(5) + '.athdf', 0)
#      28     r, P = get_prim('SN.out1.' + str(i).zfill(5) + '.athdf', 1)
#
# <ipython-input-44-73e077df6c69> in get_uov(filename, custom)
#       3     f = h5py.File(filename, 'r')
#       4     dataset = f['hydro']
# ----> 5     dd = np.array(dataset).reshape(2,7000)
#       6     r = f['x1v'][0]
#       7     return r, dd[custom]
#
# ValueError: cannot reshape array of size 4096 into shape (2,7000)

# %%
import h5py
f = h5py.File('SN.out2.00000.athdf', 'r')

# %%
list(f.keys())
# Out:
# ['Levels',
#  'LogicalLocations',
#  'hydro',
#  'x1f',
#  'x1v',
#  'x2f',
#  'x2v',
#  'x3f',
#  'x3v']

# %%
f['hydro']
# Out:
# <HDF5 dataset "hydro": shape (2, 1, 1, 1, 7000), type ">f4">

# %%
# rho, press, vel1, vel2, vel3

# data1.colnames
plt.plot( r, dd[0], label='t=0 s' )
# plt.plot( r, data2['rho'], label=r't=$5 \times 10^4$ s' )
# plt.plot( r, data3['rho'], label=r't=$10 \times 10^4$ s' )

plt.plot( s13['col2'], s13['col4'] )

plt.ylabel(r'$\rho$ (g/cm$^3$)')
plt.xlabel(r'$r$ (cm)')
plt.legend()
plt.yscale('log')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-4b71dd1612d0> in <module>()
#       2
#       3 # data1.colnames
# ----> 4 plt.plot( r, dd[0], label='t=0 s' )
#       5 # plt.plot( r, data2['rho'], label=r't=$5 \times 10^4$ s' )
#       6 # plt.plot( r, data3['rho'], label=r't=$10 \times 10^4$ s' )
#
# NameError: name 'r' is not defined

# %%
s13 = Table.read('s13.0_profile.dat', format='ascii')
# s13[s13['col1'] > 2e13]
s13
# Out:
# <Table length=704>
#          col1                 col2        ...          col6
#        float64              float64       ...        float64
# ---------------------- ------------------ ... ----------------------
# 4.8727694745440654e+33   3640311846.97243 ...  2.875001481414931e+19
# 4.8837931201543804e+33  3705896451.485949 ... 2.7199464495873024e+19
# 4.8957473307445224e+33   3777336600.80502 ...   2.56292824955156e+19
#   4.90589859797584e+33  3838256852.671865 ... 2.4225540452390973e+19
#  4.916906583656216e+33 3904592694.5203505 ... 2.2962806292421657e+19
#  4.928843590729138e+33 3976850503.4638677 ... 2.1681830850489995e+19
# 4.9389800935931995e+33 4038465767.4633226 ...  2.053460320269811e+19
# 4.9499718647670144e+33  4105552884.947232 ...  1.950117094318953e+19
# 4.9618910675885185e+33  4178620094.325142 ... 1.8451153408588538e+19
# 4.9720122964203295e+33 4240917580.0134664 ... 1.7508881817258177e+19
#                    ...                ... ...                    ...
# 2.3006049068767196e+34  48382081017846.52 ...     28.842221886484786
#  2.300620144406538e+34  48415216118912.83 ...     25.056592728397415
#  2.300632475216393e+34 48445588190097.664 ...      21.99411254478745
# 2.3006424105555457e+34  48473011164260.16 ...     19.526795281617638
#  2.300650381081401e+34  48497382274415.94 ...     17.547099664661282
# 2.3006567476223267e+34  48518691897594.12 ...     15.965138165791794
#  2.300663902720257e+34  48544993095009.46 ...     14.475768437584517
# 2.3006701493073715e+34   48570431203705.1 ...     13.002778585844935
#  2.300676587482889e+34  48599615326400.17 ...     11.611495696599814
# 2.3006807355219464e+34  48620319271605.79 ...     10.453140360541303

# %%
plt.plot( s13['col2'], s13['col1'] )

# %%
s13['col1']
# Out:
# <Column name='col1' dtype='float64' length=704>
# 4.8727694745440654e+33
# 4.8837931201543804e+33
# 4.8957473307445224e+33
#   4.90589859797584e+33
#  4.916906583656216e+33
#  4.928843590729138e+33
# 4.9389800935931995e+33
# 4.9499718647670144e+33
# 4.9618910675885185e+33
# 4.9720122964203295e+33
# 4.9829873010282914e+33
#  4.994888101627346e+33
#                    ...
#  2.300563191885583e+34
#  2.300586158983862e+34
# 2.3006049068767196e+34
#  2.300620144406538e+34
#  2.300632475216393e+34
# 2.3006424105555457e+34
#  2.300650381081401e+34
# 2.3006567476223267e+34
#  2.300663902720257e+34
# 2.3006701493073715e+34
#  2.300676587482889e+34
# 2.3006807355219464e+34

# %%
4.87e33 + np.trapz(  (data1['rho']*4.*np.pi*data1['x1v']**2)[:5209], 
                   data1['x1v'][:5209] )

# %%
'%.2e' % data1['x1v'][5209]

# %%
np.argmin( (data1['x1v']-1e13)**2 )

# %%
plt.plot(data1['x1v'], data1['vel1'])
