# %%
# %matplotlib inline
# fix DPI issues on mac
# %config InlineBackend.figure_format = 'retina'
 # autoreload workflow, reload modules every time cell is run
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
default_color_list = plt.rcParams['axes.prop_cycle'].by_key()['color'] # get default colors
import matplotlib
matplotlib.rcParams['figure.figsize'] = 10,8 # have to fix figure size due to backend
from astropy.io import ascii   
from scipy.special import erf

# %%
# default_names = ['i', 'x1v', 'rho', 'press', 'vel1', 'vel2', 'vel3', 'Er', 
#                  'Fr1', 'Fr2', 'Fr3', 'Pr', 'Er0', 'Fr01', 'Fr02', 'Fr03', 
#                  'Sigma_s', 'Sigma_a', 'Sigma_p']
# dummies = ['dum%d' % i for i in range(27-len(default_names))]

# %%
default_names = ['i', 'x1v', 'rho', 'Pres', 'vel1', 'vel2', 'vel3']
dummies = []

# %%
data1 = ascii.read("./SN.block0.out1.00000.tab",
                   format='no_header', data_start=2,
                  names= default_names+dummies)  
data2 = ascii.read("./SN.block0.out1.00010.tab", 
                   format='no_header', data_start=2,
                  names= default_names+dummies)
data3 = ascii.read("./SN.block0.out1.00020.tab", 
                   format='no_header', data_start=2,
                  names= default_names+dummies)

# data1.colnames
plt.plot( data1['x1v'], data1['rho'], label='t=0 s' )
plt.plot( data2['x1v'], data2['rho'], label=r't=$20 \times 10^4$ s' )
plt.plot( data3['x1v'], data3['rho'], label=r't=$10 \times 10^4$ s' )


plt.ylabel(r'$\rho$ (g/cm$^3$)')
plt.xlabel(r'$r$ (cm)')
plt.legend()
# plt.yscale('log')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/zequnl/anaconda3/lib/python3.6/site-packages/astropy/io/ascii/ui.py in _guess(table, read_kwargs, format, fast_reader)
#     487             reader = get_reader(**read_kwargs)
# --> 488             dat = reader.read(table)
#     489             _read_trace.append({'kwargs': read_kwargs,
#
# /home/zequnl/anaconda3/lib/python3.6/site-packages/astropy/io/ascii/core.py in read(self, table)
#    1170         # Make sure columns are valid
# -> 1171         self.header.check_column_names(self.names, self.strict_names, self.guessing)
#    1172
#
# /home/zequnl/anaconda3/lib/python3.6/site-packages/astropy/io/ascii/core.py in check_column_names(self, names, strict_names, guessing)
#     666             raise ValueError('Length of names argument ({0}) does not match number'
# --> 667                              ' of table columns ({1})'.format(len(names), len(self.colnames)))
#     668
#
# ValueError: Length of names argument (7) does not match number of table columns (4)
#
# During handling of the above exception, another exception occurred:
#
# InconsistentTableError                    Traceback (most recent call last)
# <ipython-input-8-793c2dc5e933> in <module>()
#       1 data1 = ascii.read("./SN.block0.out1.00000.tab",
#       2                    format='no_header', data_start=2,
# ----> 3                   names= default_names+dummies)
#       4 data2 = ascii.read("./SN.block0.out1.00010.tab",
#       5                    format='no_header', data_start=2,
#
# /home/zequnl/anaconda3/lib/python3.6/site-packages/astropy/io/ascii/ui.py in read(table, guess, **kwargs)
#     323         # through below to the non-guess way so that any problems result in a
#     324         # more useful traceback.
# --> 325         dat = _guess(table, new_kwargs, format, fast_reader_param)
#     326         if dat is None:
#     327             guess = False
#
# /home/zequnl/anaconda3/lib/python3.6/site-packages/astropy/io/ascii/ui.py in _guess(table, read_kwargs, format, fast_reader)
#     516                    '************************************************************************']
#     517             lines.extend(msg)
# --> 518             raise core.InconsistentTableError('\n'.join(lines))
#     519
#     520
#
# InconsistentTableError:
# ERROR: Unable to guess table format with the guesses listed below:
# Reader:FastNoHeader data_start: 2 fill_values: [('', '0')] names: ['i', 'x1v', 'rho', 'Pres', 'vel1', 'vel2', 'vel3']
# Reader:NoHeader data_start: 2 delimiter: '|' fill_values: [('', '0')] names: ['i', 'x1v', 'rho', 'Pres', 'vel1', 'vel2', 'vel3'] quotechar: '"'
# Reader:NoHeader data_start: 2 delimiter: '|' fill_values: [('', '0')] names: ['i', 'x1v', 'rho', 'Pres', 'vel1', 'vel2', 'vel3'] quotechar: "'"
# Reader:NoHeader data_start: 2 delimiter: ',' fill_values: [('', '0')] names: ['i', 'x1v', 'rho', 'Pres', 'vel1', 'vel2', 'vel3'] quotechar: '"'
# Reader:NoHeader data_start: 2 delimiter: ',' fill_values: [('', '0')] names: ['i', 'x1v', 'rho', 'Pres', 'vel1', 'vel2', 'vel3'] quotechar: "'"
# Reader:NoHeader data_start: 2 delimiter: ' ' fill_values: [('', '0')] names: ['i', 'x1v', 'rho', 'Pres', 'vel1', 'vel2', 'vel3'] quotechar: '"'
# Reader:NoHeader data_start: 2 delimiter: ' ' fill_values: [('', '0')] names: ['i', 'x1v', 'rho', 'Pres', 'vel1', 'vel2', 'vel3'] quotechar: "'"
# Reader:NoHeader data_start: 2 delimiter: '\\s' fill_values: [('', '0')] names: ['i', 'x1v', 'rho', 'Pres', 'vel1', 'vel2', 'vel3'] quotechar: '"'
# Reader:NoHeader data_start: 2 delimiter: '\\s' fill_values: [('', '0')] names: ['i', 'x1v', 'rho', 'Pres', 'vel1', 'vel2', 'vel3'] quotechar: "'"
# Reader:NoHeader data_start: 2 fill_values: [('', '0')] names: ['i', 'x1v', 'rho', 'Pres', 'vel1', 'vel2', 'vel3']
#
# ************************************************************************
# ** ERROR: Unable to guess table format with the guesses listed above. **
# **                                                                    **
# ** To figure out why the table did not read, use guess=False and      **
# ** appropriate arguments to read().  In particular specify the format **
# ** and any known attributes like the delimiter.                       **
# ************************************************************************

# %%
from matplotlib import animation, rc
from IPython.display import HTML

# %%
# First set up the figure, the axis, and the plot element we want to animate
fig, ax = plt.subplots()

ax.set_xlim(( np.min(data1['x1v']), np.max(data1['x1v'])))
ax.set_ylim((1e-15,1e-7))
# ax.set_yscale('log')

line, = ax.plot([], [], lw=2)

# %%
# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return (line,)

# %%
# animation function. This is called sequentially
def animate(i):
    datai = ascii.read('./SN.block0.out1.' + str(i).zfill(5) + '.tab',
                   format='no_header', data_start=2,
                  names= default_names+dummies)  
    line.set_data(datai['x1v'], datai['rho'])
    return (line,)

# %%
# call the animator. blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=1000, interval=20, blit=True)
HTML(anim.to_html5_video())
# Out:
# <video width="720" height="576" controls autoplay loop>
#   <source type="video/mp4" src="...
