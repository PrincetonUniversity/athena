# %%
# %matplotlib inline
# fix DPI issues on mac
# %config InlineBackend.figure_format = 'retina'
 # autoreload workflow, reload modules every time cell is run
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
default_color_list = plt.rcParams['axes.prop_cycle'].by_key()['color'] # get default colors
import matplotlib
matplotlib.rcParams['figure.figsize'] = 10,8 # have to fix figure size due to backend
from astropy.io import ascii   
from scipy.special import erf

# %%
# default_names = ['i', 'x1v', 'rho', 'press', 'vel1', 'vel2', 'vel3', 'Er', 
#                  'Fr1', 'Fr2', 'Fr3', 'Pr', 'Er0', 'Fr01', 'Fr02', 'Fr03', 
#                  'Sigma_s', 'Sigma_a', 'Sigma_p']
# dummies = ['dum%d' % i for i in range(27-len(default_names))]

# %%
default_names = ['i', 'x1v', 'rho', 'Pres', 'vel1', 'vel2', 'vel3']
dummies = []

# %%
import yt

# Load the dataset.
ds = yt.load("SN.out1.00001.athdf")
# Out:
# yt : [WARNING  ] 2018-03-15 23:53:57,847 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2018-03-15 23:53:57,848 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2018-03-15 23:53:57,849 Assuming 1.0 = 1.0 g
# yt : [WARNING  ] 2018-03-15 23:53:57,850 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2018-03-15 23:53:57,864 Parameters: current_time              = 112470.21642110628
# yt : [INFO     ] 2018-03-15 23:53:57,865 Parameters: domain_dimensions         = [256 128   1]
# yt : [INFO     ] 2018-03-15 23:53:57,866 Parameters: domain_left_edge          = [1.e+13 0.e+00 0.e+00]
# yt : [INFO     ] 2018-03-15 23:53:57,867 Parameters: domain_right_edge         = [6.00000000e+13 3.14159265e+00 6.28318531e+00]
# yt : [INFO     ] 2018-03-15 23:53:57,868 Parameters: cosmological_simulation   = 0.0

# %%
slc = yt.SlicePlot(ds, 'phi', 'rho', center=[0.0, 0.0, 0.0])
slc.show()
# Out:
# yt : [INFO     ] 2018-03-15 23:53:58,176 Setting origin='native' for spherical geometry.
# yt : [INFO     ] 2018-03-15 23:53:58,357 xlim = 5000000000000.000000 65000000000000.000000
# yt : [INFO     ] 2018-03-15 23:53:58,358 ylim = -50000000000000.000000 50000000000000.000000
# yt : [INFO     ] 2018-03-15 23:53:58,360 xlim = 5000000000000.000000 65000000000000.000000
# yt : [INFO     ] 2018-03-15 23:53:58,361 ylim = -50000000000000.000000 50000000000000.000000
# yt : [INFO     ] 2018-03-15 23:53:58,362 Making a fixed resolution buffer of (('athena_pp', 'rho')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
data1 = ascii.read("./SN.block0.out3.000001.tab",
                   format='no_header', data_start=2,
                  names= default_names+dummies)  

uov = ascii.read("./SN.block0.out4.00000.tab",
                   format='no_header', data_start=2,
                  names= ['i','x1v','user_out_var0', 'user_out_var1' ])  

# data1.colnames
plt.plot( data1['x1v'], -np.gradient(data1['Pres'], data1['x1v'] ), label='t=0 s' )
plt.plot( uov['x1v'], uov['user_out_var0'] * data1['rho'], '--' )


plt.ylabel(r'$\rho$ (g/cm$^3$)')
plt.xlabel(r'$r$ (cm)')
plt.legend()
plt.yscale('log')

plt.figure()

plt.plot( data1['x1v'], -np.gradient(data1['Pres'], data1['x1v'] ) / 
         ( uov['user_out_var0'] * data1['rho']), label='t=0 s' )
plt.ylim(0,3)
# plt.yscale('log')
# Out:
# (0, 3)

# %%
from matplotlib import animation, rc
from IPython.display import HTML

# %%
# First set up the figure, the axis, and the plot element we want to animate
fig, ax = plt.subplots()

ax.set_xlim(( np.min(data1['x1v']), np.max(data1['x1v'])))
ax.set_ylim((1e-15,1e-7))
# ax.set_yscale('log')

line, = ax.plot([], [], lw=2)

# %%
# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return (line,)

# %%
# animation function. This is called sequentially
def animate(i):
    datai = ascii.read('./SN.block0.out3.' + str(i).zfill(5) + '.tab',
                   format='no_header', data_start=2,
                  names= default_names+dummies)  
    line.set_data(datai['x1v'], datai['rho'])
    return (line,)

# %%
# call the animator. blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=50, interval=20, blit=True)
HTML(anim.to_html5_video())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-70-6fe55787167e> in <module>()
#       2 anim = animation.FuncAnimation(fig, animate, init_func=init,
#       3                                frames=40, interval=20, blit=True)
# ----> 4 HTML(anim.to_html5_video())
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/animation.py in to_html5_video(self, embed_limit)
#    1350                                 bitrate=rcParams['animation.bitrate'],
#    1351                                 fps=1000. / self._interval)
# -> 1352                 self.save(f.name, writer=writer)
#    1353
#    1354             # Now open and base64 encode
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs)
#    1196                     for anim, d in zip(all_anim, data):
#    1197                         # TODO: See if turning off blit is really necessary
# -> 1198                         anim._draw_next_frame(d, blit=False)
#    1199                     writer.grab_frame(**savefig_kwargs)
#    1200
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/animation.py in _draw_next_frame(self, framedata, blit)
#    1233         # post- draw, as well as the drawing of the frame itself.
#    1234         self._pre_draw(framedata, blit)
# -> 1235         self._draw_frame(framedata)
#    1236         self._post_draw(framedata, blit)
#    1237
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/animation.py in _draw_frame(self, framedata)
#    1769         # Call the func with framedata and args. If blitting is desired,
#    1770         # func needs to return a sequence of any artists that were modified.
# -> 1771         self._drawn_artists = self._func(framedata, *self._args)
#    1772         if self._blit:
#    1773             if self._drawn_artists is None:
#
# <ipython-input-55-61fd9daad332> in animate(i)
#       3     datai = ascii.read('./SN.block0.out3.' + str(i).zfill(5) + '.tab',
#       4                    format='no_header', data_start=2,
# ----> 5                   names= default_names+dummies)
#       6     line.set_data(datai['x1v'], datai['rho'])
#       7     return (line,)
#
# ~/anaconda3/lib/python3.6/site-packages/astropy/io/ascii/ui.py in read(table, guess, **kwargs)
#     349         # through below to the non-guess way so that any problems result in a
#     350         # more useful traceback.
# --> 351         dat = _guess(table, new_kwargs, format, fast_reader)
#     352         if dat is None:
#     353             guess = False
#
# ~/anaconda3/lib/python3.6/site-packages/astropy/io/ascii/ui.py in _guess(table, read_kwargs, format, fast_reader)
#     495             reader = get_reader(**guess_kwargs)
#     496             reader.guessing = True
# --> 497             dat = reader.read(table)
#     498             _read_trace.append({'kwargs': guess_kwargs,
#     499                                 'Reader': reader.__class__,
#
# ~/anaconda3/lib/python3.6/site-packages/astropy/io/ascii/fastbasic.py in read(self, table)
#     107                                       data_start=self.data_start,
#     108                                       fill_extra_cols=self.fill_extra_cols,
# --> 109                                       **self.kwargs)
#     110         conversion_info = self._read_header()
#     111         self.check_header()
#
# astropy/io/ascii/cparser.pyx in astropy.io.ascii.cparser.CParser.__cinit__()
#
# astropy/io/ascii/cparser.pyx in astropy.io.ascii.cparser.CParser.setup_tokenizer()
#
# astropy/io/ascii/cparser.pyx in astropy.io.ascii.cparser.FileString.__cinit__()
#
# FileNotFoundError: [Errno 2] No such file or directory: './SN.block0.out3.00016.tab'
